# %%
import os
import time
import urllib

import cv2
import numpy as np
import torch
from IPython.display import clear_output, display
from PIL import Image

from sam2.build_sam import build_sam2_object_tracker

# %%
class Visualizer:
    def __init__(self,
                 video_width,
                 video_height,
                 ):
        
        self.video_width = video_width
        self.video_height = video_height

    def resize_mask(self, mask):
        mask = torch.tensor(mask, device='cpu')
        mask = torch.nn.functional.interpolate(mask,
                                               size=(self.video_height, self.video_width),
                                               mode="bilinear",
                                               align_corners=False,
                                               )
        
        return mask

    def add_frame(self, frame, mask):
        frame = frame.copy()
        frame = cv2.resize(frame, (self.video_width, self.video_height))
        
        mask = self.resize_mask(mask=mask)
        mask = (mask > 0.0).numpy()
        
        for i in range(mask.shape[0]):
            obj_mask = mask[i, 0, :, :]
            frame[obj_mask] = [255, 105, 180]
                
        rgb_frame = Image.fromarray(frame)
        clear_output(wait=True)
        display(rgb_frame)

# %%
# Download Example Video
VIDEO_STREAM = "./TUD-Stadtmitte-raw.webm"
url = 'https://motchallenge.net/sequenceVideos/TUD-Stadtmitte-raw.webm'

# Check if the file already exists
if not os.path.exists(VIDEO_STREAM):
    # If the file doesn't exist, download it
    urllib.request.urlretrieve(url, VIDEO_STREAM)
    print(f"Downloading {VIDEO_STREAM}...")
else:
    print(f"File {VIDEO_STREAM} already exists, skipping download.")
# Out:
# File ./TUD-Stadtmitte-raw.webm already exists, skipping download.

# %%
# Set SAM2 Configuration
NUM_OBJECTS = 2
YOLO_CHECKPOINT_FILEPATH = "yolov8x-seg.pt"
SAM_CHECKPOINT_FILEPATH = "../checkpoints/sam2.1_hiera_tiny.pt"
SAM_CONFIG_FILEPATH = "./configs/samurai/sam2.1_hiera_t.yaml"
OUTPUT_PATH = VIDEO_STREAM + "_segmented.mp4"
DEVICE = 'cuda:0'

# %%
#stream_url = "http://stage-ams-nfs.srv.axds.co/stream/adaptive/ucsc/walton_lighthouse/hls.m3u8"
stream_url = "./videos/bedroom.mp4"

# %%
# Open Video Stream
#video_stream = cv2.VideoCapture(VIDEO_STREAM)
video_stream = cv2.VideoCapture(stream_url)
video_height = int(video_stream.get(cv2.CAP_PROP_FRAME_HEIGHT))
video_width = int(video_stream.get(cv2.CAP_PROP_FRAME_WIDTH))

# For real-time visualization
visualizer = Visualizer(video_width=video_width,
                        video_height=video_height
                        )

# %%
sam = build_sam2_object_tracker(num_objects=NUM_OBJECTS,
                                config_file=SAM_CONFIG_FILEPATH,
                                ckpt_path=SAM_CHECKPOINT_FILEPATH,
                                device=DEVICE,
                                verbose=False
                                )

# %%
available_slots = np.inf

first_frame = True
with torch.inference_mode(), torch.autocast('cuda:0', dtype=torch.bfloat16):
    while video_stream.isOpened():
        start_time = time.time()

        # Get next frame
        ret, frame = video_stream.read()
        # (1920, 2560)

        # Exit if no frames remaining
        if not ret:
            break

        # Convert frame from BGR to RGB
        img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # Simulate detection on first frame
        if first_frame:
            # bbox = np.array([[[172, 92], [254, 325]], 
            #                  [[334, 76],  [439, 329]]]
            #                 )
            bbox = np.array([[[0, 580], [2560, 1920]] 
                             ]
                            )            
            
            sam_out = sam.track_new_object(img=img,
                                           box=bbox
                                           )
            # Draw the initial bounding boxes
            for box in bbox:
                top_left = tuple(box[0])
                bottom_right = tuple(box[1])
                cv2.rectangle(frame, top_left, bottom_right, (0, 255, 0), 2)
            
            first_frame = False
            
        else:
            sam_out = sam.track_all_objects(img=img)
            
        visualizer.add_frame(frame=frame, mask=sam_out['pred_masks'])
        
video_stream.release()
# Out:
# <PIL.Image.Image image mode=RGB size=960x540>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 40
#      37             first_frame = False
#      39         else:
# ---> 40             sam_out = sam.track_all_objects(img=img)
#      42         visualizer.add_frame(frame=frame, mask=sam_out['pred_masks'])
#      44 video_stream.release()
#
# File c:\Users\remote\anaconda3\envs\sam2_realtime_env\lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~\Documents\GitHub\sam2_realtime\sam2\sam2_object_tracker.py:1080, in SAM2ObjectTracker.track_all_objects(self, img)
#    1077 image_embedding_time = time.time() - start_time
#    1078 start_time = time.time()
# -> 1080 prediction = self.inference(current_vision_feats=current_vision_feats,
#    1081                             current_vision_pos_embeds=current_vision_pos_embeds,
#    1082                             feat_sizes=feat_sizes,
#    1083                             point_inputs=None,
#    1084                             mask_inputs=None,
#    1085                             run_mem_encoder=True,
#    1086                             prev_sam_mask_logits=None
#    1087                             )
#    1089 inference_time = time.time() - start_time
#    1090 start_time = time.time()
#
# File ~\Documents\GitHub\sam2_realtime\sam2\sam2_object_tracker.py:718, in SAM2ObjectTracker.inference(self, current_vision_feats, current_vision_pos_embeds, feat_sizes, point_inputs, mask_inputs, run_mem_encoder, prev_sam_mask_logits)
#     715     init_frame = not self.past_frames['short_term'] and not self.past_frames['long_term']
#     716     multimask_output = self._use_multimask(init_frame, point_inputs)
# --> 718     sam_outputs = self.forward_sam_heads(backbone_features=pix_feat_with_mem,
#     719                                          point_inputs=point_inputs,
#     720                                          mask_inputs=mask_inputs,
#     721                                          high_res_features=high_res_features,
#     722                                          multimask_output=multimask_output,
#     723                                          )
#     725     _, _, _, low_res_masks, high_res_masks, obj_ptr, object_score_logits, ious, kf_ious = sam_outputs
#     727 current_out["pred_masks"] = low_res_masks
#
# File ~\Documents\GitHub\sam2_realtime\sam2\sam2_object_tracker.py:378, in SAM2ObjectTracker.forward_sam_heads(self, backbone_features, point_inputs, mask_inputs, high_res_features, multimask_output)
#     375 kf_ious = []
#     377 for obj in range(0, B):
# --> 378     out = self.update_kalman_filter(obj=obj,
#     379                                     ious=ious,
#     380                                     low_res_multimasks=low_res_multimasks,
#     381                                     high_res_multimasks=high_res_multimasks,
#     382                                     sam_output_tokens=sam_output_tokens
#     383                                     )
#     385     _low_res_masks, _high_res_masks, _sam_output_token, _ious, _kf_ious = out
#     387     low_res_masks.append(_low_res_masks)
#
# File ~\Documents\GitHub\sam2_realtime\sam2\sam2_object_tracker.py:142, in SAM2ObjectTracker.update_kalman_filter(self, obj, ious, low_res_multimasks, high_res_multimasks, sam_output_tokens)
#     138 self.kf_covariance[obj] = kf_covariance
#     140 best_iou_inds = torch.argmax(ious, dim=-1)
# --> 142 non_zero_indices = torch.argwhere(high_res_multimasks[best_iou_inds] > 0.0)
#     144 if len(non_zero_indices) == 0:
#     145     high_res_bbox = [0, 0, 0, 0]
#
# KeyboardInterrupt:
